# %%
import pandas as pd

df = pd.read_csv('Cardiotocographic.csv')
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.340204     0.003204     0.009894     0.004391     0.001895
# std      11.214379     0.004373     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000002     0.000173    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %% [markdown]
# There are some blanks present in some of the columns. Hence, we can replace the blanks with median value of that particular column.

# %%
df_blanks = df[['LB', 'AC', 'DS', 'DP', 'MLTV', 'Width', 'Tendency', 'NSP']]
for i in df_blanks.columns:
    df[i].fillna(value = df_blanks[i].median(), inplace = True)

df.isnull().sum()
# Out:
# C:\Users\cs833\AppData\Local\Temp\ipykernel_19040\319749698.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(value = df_blanks[i].median(), inplace = True)
# C:\Users\cs833\AppData\Local\Temp\ipykernel_19040\319749698.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.062813  0.018807 -0.166229 -0.126563 -0.005432
# AC       -0.062813  1.000000  0.009768  0.071621 -0.093449 -0.033088
# FM        0.018807  0.009768  1.000000 -0.053226  0.009718  0.029916
# UC       -0.166229  0.071621 -0.053226  1.000000  0.190128 -0.006938
# DL       -0.126563 -0.093449  0.009718  0.190128  1.000000  0.058413
# DS       -0.005432 -0.033088  0.029916 -0.006938  0.058413  1.000000
# DP       -0.047650 -0.083298  0.121459  0.070295  0.144717  0.004321
# ASTV      0.241857 -0.230470 -0.032691 -0.181161 -0.069361  0.008426
# MSTV     -0.169647  0.132962  0.017055  0.189406  0.410102  0.016026
# ALTV      0.210542 -0.269807 -0.011936 -0.227304 -0.186967 -0.004335
# MLTV     -0.003423 -0.104853 -0.006121 -0.049452 -0.165293  0.034367
# Width    -0.118397  0.234549  0.097282  0.107083  0.408578  0.040845
# Tendency  0.236730  0.031710 -0.017819 -0.066832 -0.023914 -0.015294
# ...

# %%
df['NSP'].value_counts()
# Out:
# NSP
#  1.000000    1567
#  2.000000     280
#  3.000000     164
# -1.000000       5
#  5.000000       4
#              ...
#  0.993695       1
#  1.013864       1
#  0.989862       1
#  1.004234       1
#  1.990464       1
# Name: count, Length: 111, dtype: int64

# %%
# Visualize correlations on Heat map
import seaborn as sns
import matplotlib.pyplot as plt

correlation = df.corr().round(3)
plt.figure(figsize=(11, 8))
sns.heatmap(correlation, annot=True, cmap = 'coolwarm')  # Visualize correlations as heatmap
plt.show()

# %% [markdown]
# Hence, there is no high correlation between any of X variables in the given dataset.

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.340204     0.003204     0.009894     0.004391     0.001895
# std      11.214379     0.004373     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000002     0.000173    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
import seaborn as sns

plt.figure(figsize=(15, 10))

sns.boxplot(
    data=df,
    orient='h'
)

plt.suptitle('Boxplots of all columns')
plt.xticks(rotation=45) 

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Hence, we can see the outliers present in the columns like LB, ASTV, MSTV, ALTV, MLTV, NSP etc.

# %%
import numpy as np # type: ignore

def replace_outliers_with_median(df):
  """
  Replaces outliers in each column of a DataFrame with the median of that column,
  excluding the outliers themselves.

  Args:
    df: A pandas DataFrame.

  Returns:
    A new pandas DataFrame with outliers replaced by median values.
  """
  new_df = df.copy()

  # Iterate over numeric columns
  for col in new_df.select_dtypes(include=[np.number]):
    # Define IQR outlier threshold function (adjust multiplier as needed)
    def is_outlier(series):
      q1 = series.quantile(0.25)
      q3 = series.quantile(0.75)
      iqr = q3 - q1
      lower_bound = q1 - (1.5 * iqr)
      upper_bound = q3 + (1.5 * iqr)
      return ~((series >= lower_bound) & (series <= upper_bound))

    # Find outliers (boolean Series)
    outliers = is_outlier(new_df[col])
    
    # Replace outliers with median (excluding outliers in median calculation)
    median_val = new_df.loc[~outliers, col].median()
    new_df.loc[outliers, col] = median_val

  return new_df

X = replace_outliers_with_median(df)
print(X)
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.000000  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV  ALTV  MLTV  Width  Tendency  NSP
# 0      0.5   0.0   2.4   64.0  0.999926  1.0
# ...

# %% [markdown]
# The outliers present in the columns of the dataset are replaced with the median value of that column without outliers.

# %%
fig, axes = plt.subplots(7, 2, figsize=(13, 20))  # 7 rows, 2 columns
axes = axes.flatten()

for i, col in enumerate(df.columns):
    sns.histplot(df[col], ax=axes[i], kde=True)
    axes[i].set_title(f'Histogram of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# Here, the distribution of LB appears to be normal distribution, which is typical characteristic for the healthy fetuses.

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
# Counts the occurences in UC (Uterine Contractions)

uc_counts = df['Width'].value_counts()  # Count occurrences in 'UC' column

plt.bar(uc_counts.index, uc_counts.values)  # Plot bars
plt.xlabel("Width")  # Label x-axis
plt.ylabel("Count")  # Label y-axis
plt.title("Distribution of Width")  # Title for the plot
plt.show()

# %%
# Count the occurences of ALTV (Percentage of time with Abnormal long term variability)

uc_counts = df['ALTV'].value_counts()  # Count occurrences in 'UC' column

plt.bar(uc_counts.index, uc_counts.values)  # Plot bars
plt.xlabel("ALTV")  # Label x-axis
plt.ylabel("Count")  # Label y-axis
plt.title("Distribution of ALTV")  # Title for the plot
plt.show()

# %%
# Count the occurences of MLTV (Mean value of Long term variability)

uc_counts = df['MLTV'].value_counts()  # Count occurrences in 'UC' column

plt.bar(uc_counts.index, uc_counts.values)  # Plot bars
plt.xlabel("MLTV")  # Label x-axis
plt.ylabel("Count")  # Label y-axis
plt.title("Distribution of MLTV")  # Title for the plot
plt.show()

# %%
# Count the occurences of MSTV (Mean value of Short term variability)

uc_counts = df['MSTV'].value_counts()  # Count occurrences in 'UC' column

plt.bar(uc_counts.index, uc_counts.values)  # Plot bars
plt.xlabel("MSTV")  # Label x-axis
plt.ylabel("Count")  # Label y-axis
plt.title("Distribution of MSTV")  # Title for the plot
plt.show()

# %%
# Count the occurences of ASTV (Percentage of Time with Abnormal short term variability)

uc_counts = df['ASTV'].value_counts()  # Count occurrences in 'UC' column

plt.bar(uc_counts.index, uc_counts.values)  # Plot bars
plt.xlabel("ASTV")  # Label x-axis
plt.ylabel("Count")  # Label y-axis
plt.title("Distribution of ASTV")  # Title for the plot
plt.show()

# %%
# LB (Basline FHR) Vs FM (Fetal Movements)

plt.scatter(df['LB'], df['FM'])
plt.show()

# %%
plt.scatter(df['LB'], df['AC'])
plt.show()

# %%
plt.scatter(df['MSTV'], df['MLTV'])
plt.show()

# %%
# Pair plot of all the columns
plt.figure(figsize = (20, 15))
sns.pairplot(df)
plt.show()

# %%
# Violin plot of all the columns
plt.figure(figsize = (10, 6))
sns.violinplot(data = df)
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()
